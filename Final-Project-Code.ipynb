# %% [markdown]
# ## Data Processing

# %%
# !pip install tabulate

# %%
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency
import seaborn as sns
import matplotlib.pyplot as plt
from tabulate import tabulate
import statsmodels.api as sm 
from statsmodels.formula.api import glm
# %matplotlib inline

# %%
df=pd.read_csv('resume.csv')

# %%
df
# Out:
#       job_ad_id job_city                   job_industry    job_type  \
# 0           384  Chicago                  manufacturing  supervisor
# 1           384  Chicago                  manufacturing  supervisor
# 2           384  Chicago                  manufacturing  supervisor
# 3           384  Chicago                  manufacturing  supervisor
# 4           385  Chicago                  other_service   secretary
# ...         ...      ...                            ...         ...
# 4865       1344   Boston  finance_insurance_real_estate   secretary
# 4866        382   Boston                  other_service     manager
# 4867        382   Boston                  other_service     manager
# 4868        382   Boston                  other_service     manager
# 4869        382   Boston                  other_service     manager
#
#       job_fed_contractor  job_equal_opp_employer job_ownership  job_req_any  \
# 0                    NaN                       1       unknown            1
# 1                    NaN                       1       unknown            1
# 2                    NaN                       1       unknown            1
# 3                    NaN                       1       unknown            1
# 4                    0.0                       1     nonprofit            1
# ...                  ...                     ...           ...          ...
# 4865                 0.0                       0       private            1
# 4866                 NaN                       0       unknown            0
# 4867                 NaN                       0       unknown            0
# 4868                 NaN                       0       unknown            0
# 4869                 NaN                       0       unknown            0
#
#       job_req_communication  job_req_education  ... honors  \
# 0                         0                  0  ...      0
# 1                         0                  0  ...      0
# 2                         0                  0  ...      0
# 3                         0                  0  ...      0
# 4                         0                  0  ...      0
# ...                     ...                ...  ...    ...
# 4865                      0                  0  ...      0
# 4866                      0                  0  ...      0
# 4867                      0                  0  ...      0
# 4868                      0                  0  ...      0
# 4869                      0                  0  ...      0
#
#       worked_during_school  years_experience computer_skills  special_skills  \
# 0                        0                 6               1               0
# 1                        1                 6               1               0
# 2                        1                 6               1               0
# 3                        0                 6               1               1
# 4                        1                22               1               0
# ...                    ...               ...             ...             ...
# 4865                     0                 1               1               1
# 4866                     1                 6               1               0
# 4867                     1                 8               1               0
# 4868                     1                 2               1               0
# 4869                     0                 7               0               0
#
#      volunteer military employment_holes  has_email_address  resume_quality
# 0            0        0                1                  0             low
# 1            1        1                0                  1            high
# 2            0        0                0                  0             low
# 3            1        0                1                  1            high
# 4            0        0                0                  1            high
# ...        ...      ...              ...                ...             ...
# 4865         0        0                1                  0             low
# 4866         0        0                0                  0             low
# 4867         1        0                0                  1            high
# 4868         1        1                0                  1            high
# 4869         0        0                1                  0             low
#
# [4870 rows x 30 columns]

# %%
df.reset_index()
# Out:
#       index  job_ad_id job_city                job_industry      job_type  \
# 0         4        385  Chicago               other_service     secretary
# 1         7        385  Chicago               other_service     secretary
# 2        10        387  Chicago               other_service     secretary
# 3        11        387  Chicago               other_service     secretary
# 4        23        391  Chicago               other_service     secretary
# ...     ...        ...      ...                         ...           ...
# 1497   4821         78   Boston  wholesale_and_retail_trade  retail_sales
# 1498   4858        381   Boston  wholesale_and_retail_trade  retail_sales
# 1499   4859        381   Boston  wholesale_and_retail_trade  retail_sales
# 1500   4860        381   Boston  wholesale_and_retail_trade  retail_sales
# 1501   4861        381   Boston  wholesale_and_retail_trade  retail_sales
#
#       job_fed_contractor  job_equal_opp_employer job_ownership  job_req_any  \
# 0                    0.0                       1     nonprofit            1
# 1                    0.0                       1     nonprofit            1
# 2                    0.0                       1     nonprofit            1
# 3                    0.0                       1     nonprofit            1
# 4                    1.0                       0     nonprofit            1
# ...                  ...                     ...           ...          ...
# 1497                 0.0                       0       private            1
# 1498                 0.0                       0       private            1
# 1499                 0.0                       0       private            1
# 1500                 0.0                       0       private            1
# 1501                 0.0                       0       private            1
#
#       job_req_communication  ...  honors worked_during_school  \
# 0                         0  ...       0                    1
# 1                         0  ...       0                    0
# 2                         0  ...       0                    0
# 3                         0  ...       0                    1
# 4                         0  ...       0                    0
# ...                     ...  ...     ...                  ...
# 1497                      0  ...       0                    1
# 1498                      0  ...       0                    1
# 1499                      0  ...       0                    1
# 1500                      0  ...       0                    1
# 1501                      0  ...       0                    0
#
#       years_experience  computer_skills special_skills  volunteer military  \
# 0                   22                1              0          0        0
# 1                   21                1              1          1        0
# 2                    8                1              1          1        0
# 3                    8                1              0          0        0
# 4                    7                1              0          0        0
# ...                ...              ...            ...        ...      ...
# 1497                 6                1              0          0        0
# 1498                 2                1              0          1        1
# 1499                 6                1              0          0        0
# 1500                 8                1              0          1        0
# 1501                 7                0              0          0        0
#
#      employment_holes has_email_address  resume_quality
# 0                   0                 1            high
# 1                   1                 1            high
# 2                   1                 1            high
# 3                   0                 1            high
# 4                   1                 0             low
# ...               ...               ...             ...
# 1497                0                 0             low
# 1498                0                 1            high
# 1499                0                 0             low
# 1500                0                 1            high
# 1501                1                 0             low
#
# [1502 rows x 31 columns]

# %%
#Make a list of all the unique names
unique_names = df['firstname'].unique()

# %%
#Print all names to make categories
unique_names
# Out:
# array(['Carrie', 'Kenya', 'Aisha', 'Allison', 'Keisha', 'Kristen',
#        'Lakisha', 'Jill', 'Meredith', 'Ebony', 'Jay', 'Laurie', 'Tyrone',
#        'Anne', 'Latonya', 'Jamal', 'Matthew', 'Neil', 'Leroy', 'Todd',
#        'Brett', 'Darnell', 'Jermaine', 'Latoya', 'Tamika', 'Geoffrey',
#        'Rasheed', 'Brad', 'Sarah', 'Tanisha', 'Kareem', 'Emily', 'Greg',
#        'Hakim', 'Brendan', 'Tremayne'], dtype=object)

# %%
#Make name categories
white_male_names=[ 'Matthew', 'Neil', 'Leroy', 'Todd','Brett','Geoffrey','Brad','Greg','Brendan','Jay',]
white_female_names=['Carrie','Allison','Kristen','Anne', 'Sarah', 'Emily','Laurie','Jill', 'Meredith', 'Anne']
black_male_names=['Jamal','Darnell', 'Jermaine','Rasheed','Kareem','Hakim','Tremayne','Tyrone', ]
black_female_names=['Kenya', 'Aisha','Keisha','Latonya','Latoya', 'Tamika','Tanisha','Ebony','Lakisha' ]

# %%
# #Replace names with their respective category

# df['firstname']=df['firstname'].replace(white_male_names,1)
# df['firstname']=df['firstname'].replace(white_female_names,2)
# df['firstname']=df['firstname'].replace(black_male_names,3)
# df['firstname']=df['firstname'].replace(black_female_names,4)

# %%
#Replace names with their respective category
df['received_callback']=df['received_callback'].replace(0,2)
df['firstname']=df['firstname'].replace(white_male_names,1)
df['firstname']=df['firstname'].replace(white_female_names,1)
df['firstname']=df['firstname'].replace(black_male_names,2)
df['firstname']=df['firstname'].replace(black_female_names,2)

# %%
#Check to make sure we did not miss any names
df['firstname'].unique()

# %% [markdown]
# # Chi-square test of independence.

# %%
all_col = df.columns.values
print(all_col)
# Out:
# ['job_ad_id' 'job_city' 'job_industry' 'job_type' 'job_fed_contractor'
#  'job_equal_opp_employer' 'job_ownership' 'job_req_any'
#  'job_req_communication' 'job_req_education' 'job_req_min_experience'
#  'job_req_computer' 'job_req_organization' 'job_req_school'
#  'received_callback' 'firstname' 'race' 'gender' 'years_college'
#  'college_degree' 'honors' 'worked_during_school' 'years_experience'
#  'computer_skills' 'special_skills' 'volunteer' 'military'
#  'employment_holes' 'has_email_address' 'resume_quality']

# %%
Dep_variables = ['received_callback']
excluded_columns = {'received_callback'}
Indep_variables = [col for col in all_col if col not in excluded_columns]

# %%
def Chi_square_table_test(df,v1,v2):
    contigency= pd.crosstab(df[v1], df[v2])
    contigency_pct= pd.crosstab(df[v1], df[v2],normalize='index') 
    print(tabulate(contigency, headers='keys', tablefmt='psql'))
    print(tabulate(contigency_pct, headers='keys', tablefmt='psql'))
    c, p, dof, expected = chi2_contingency(contigency) 
    print(f"The p-value (Chi-square test of independenc: {v1} and {v2} ):\n{p}")

# %%
for i in Indep_variables:
    for j in Dep_variables:
        print(j)
        Chi_square_table_test(df,i,j)
        print("\n")
    print("------------------------------------------------------------------------------------------------------------------------------------------------------")
# Out:
# received_callback
# +-------------+-----+-----+
# |   job_ad_id |   1 |   2 |
# |-------------+-----+-----|
# |           1 |   0 |   4 |
# |           2 |   0 |   4 |
# |           3 |   0 |   4 |
# |           4 |   0 |   4 |
# |           6 |   0 |   4 |
# |           8 |   0 |   4 |
# |          11 |   0 |   4 |
# |          12 |   0 |   4 |
# |          13 |   0 |   4 |
# |          14 |   0 |   4 |
# |          20 |   0 |   4 |
# |          21 |   0 |   4 |
# |          23 |   0 |   4 |
# |          25 |   0 |   4 |
# |          31 |   0 |   4 |
# |          32 |   0 |   4 |
# |          33 |   0 |   4 |
# |          36 |   0 |   4 |
# |          38 |   0 |   4 |
# |          39 |   0 |   4 |
# |          40 |   2 |   2 |
# |          45 |   0 |   4 |
# |          46 |   0 |   4 |
# |          50 |   0 |   4 |
# |          57 |   0 |   4 |
# |          60 |   0 |   4 |
# |          61 |   0 |   4 |
# |          62 |   0 |   4 |
# |          63 |   0 |   4 |
# |          64 |   0 |   4 |
# |          66 |   0 |   4 |
# |          69 |   0 |   4 |
# |          70 |   0 |   4 |
# |          73 |   0 |   4 |
# |          76 |   0 |   4 |
# |          77 |   0 |   4 |
# |          78 |   0 |   4 |
# |          80 |   0 |   4 |
# |          81 |   0 |   4 |
# |          84 |   0 |   4 |
# |          86 |   0 |   4 |
# |          87 |   1 |   3 |
# |          95 |   0 |   4 |
# |          97 |   0 |   4 |
# |          99 |   0 |   4 |
# |         100 |   0 |   4 |
# |         101 |   2 |   2 |
# |         103 |   0 |   4 |
# |         104 |   0 |   4 |
# |         105 |   0 |   4 |
# |         107 |   0 |   4 |
# |         110 |   0 |   4 |
# |         111 |   0 |   4 |
# |         114 |   0 |   4 |
# |         116 |   0 |   4 |
# |         117 |   0 |   4 |
# |         122 |   0 |   4 |
# |         124 |   0 |   4 |
# |         125 |   0 |   4 |
# |         126 |   0 |   4 |
# |         127 |   0 |   4 |
# |         129 |   0 |   4 |
# |         130 |   0 |   4 |
# |         131 |   0 |   4 |
# |         133 |   0 |   4 |
# |         134 |   0 |   4 |
# |         135 |   0 |   4 |
# |         137 |   0 |   4 |
# |         143 |   0 |   4 |
# |         145 |   0 |   4 |
# |         146 |   0 |   4 |
# |         148 |   0 |   4 |
# |         153 |   0 |   4 |
# |         155 |   0 |   4 |
# |         158 |   0 |   4 |
# |         161 |   0 |   4 |
# |         162 |   0 |   4 |
# |         163 |   0 |   4 |
# |         164 |   0 |   4 |
# |         168 |   0 |   4 |
# |         169 |   0 |   4 |
# |         170 |   0 |   4 |
# |         173 |   0 |   4 |
# |         174 |   0 |   4 |
# |         177 |   0 |   4 |
# |         178 |   4 |   0 |
# |         179 |   0 |   4 |
# |         182 |   0 |   4 |
# |         185 |   0 |   4 |
# |         186 |   0 |   4 |
# |         187 |   0 |   4 |
# |         188 |   0 |   4 |
# |         189 |   0 |   4 |
# |         190 |   0 |   4 |
# |         191 |   0 |   4 |
# |         193 |   0 |   4 |
# |         196 |   0 |   4 |
# |         201 |   0 |   4 |
# |         203 |   0 |   4 |
# |         206 |   0 |   4 |
# |         207 |   0 |   4 |
# |         210 |   0 |   4 |
# |         218 |   0 |   4 |
# |         220 |   0 |   4 |
# |         224 |   0 |   4 |
# |         225 |   0 |   4 |
# |         226 |   0 |   4 |
# |         227 |   0 |   4 |
# |         228 |   0 |   4 |
# |         229 |   0 |   4 |
# |         234 |   0 |   4 |
# |         237 |   0 |   4 |
# |         240 |   0 |   4 |
# |         244 |   0 |   4 |
# |         245 |   0 |   4 |
# |         246 |   0 |   4 |
# |         254 |   1 |   3 |
# |         259 |   0 |   4 |
# |         261 |   0 |   4 |
# |         264 |   0 |   4 |
# |         266 |   0 |   4 |
# |         272 |   0 |   4 |
# |         275 |   0 |   4 |
# |         279 |   0 |   4 |
# |         282 |   0 |   4 |
# |         285 |   0 |   4 |
# |         288 |   2 |   2 |
# |         295 |   0 |   4 |
# |         298 |   0 |   4 |
# |         305 |   1 |   3 |
# |         319 |   0 |   2 |
# |         320 |   1 |   3 |
# |         321 |   0 |   4 |
# |         331 |   0 |   4 |
# |         333 |   2 |   2 |
# |         335 |   0 |   4 |
# |         341 |   3 |   1 |
# |         345 |   0 |   4 |
# |         346 |   0 |   4 |
# |         348 |   0 |   4 |
# |         353 |   0 |   4 |
# |         354 |   3 |   1 |
# |         355 |   0 |   4 |
# |         357 |   1 |   3 |
# |         358 |   0 |   4 |
# |         364 |   0 |   4 |
# |         365 |   0 |   4 |
# |         366 |   3 |   1 |
# |         369 |   0 |   4 |
# |         370 |   1 |   3 |
# |         372 |   0 |   4 |
# |         373 |   0 |   4 |
# |         381 |   2 |   2 |
# |         385 |   0 |   2 |
# |         387 |   0 |   2 |
# |         391 |   0 |   4 |
# |         394 |   0 |   4 |
# |         399 |   0 |   4 |
# |         400 |   0 |   2 |
# |         406 |   0 |   4 |
# |         407 |   0 |   4 |
# |         410 |   1 |   1 |
# |         414 |   1 |   1 |
# |         415 |   0 |   2 |
# |         416 |   0 |   2 |
# |         418 |   2 |   0 |
# |         420 |   0 |   2 |
# |         422 |   0 |   4 |
# |         423 |   0 |   2 |
# |         424 |   0 |   2 |
# |         425 |   0 |   2 |
# |         427 |   0 |   4 |
# |         430 |   0 |   2 |
# |         431 |   0 |   4 |
# |         434 |   0 |   4 |
# |         435 |   0 |   2 |
# |         437 |   0 |   4 |
# |         441 |   2 |   0 |
# |         453 |   0 |   2 |
# |         454 |   0 |   4 |
# |         456 |   0 |   4 |
# |         458 |   1 |   3 |
# |         459 |   0 |   2 |
# |         462 |   3 |   1 |
# |         464 |   0 |   2 |
# |         465 |   0 |   4 |
# |         469 |   0 |   2 |
# |         470 |   0 |   4 |
# |         471 |   0 |   4 |
# |         473 |   0 |   4 |
# |         475 |   0 |   2 |
# |         481 |   0 |   4 |
# |         482 |   0 |   4 |
# |         485 |   1 |   3 |
# |         495 |   1 |   3 |
# |         498 |   0 |   4 |
# |         505 |   0 |   4 |
# |         507 |   0 |   4 |
# |         512 |   0 |   4 |
# |         515 |   0 |   4 |
# |         519 |   0 |   2 |
# |         523 |   0 |   4 |
# |         535 |   0 |   4 |
# |         541 |   0 |   4 |
# |         547 |   0 |   2 |
# |         551 |   0 |   4 |
# |         552 |   2 |   2 |
# |         555 |   0 |   4 |
# |         558 |   0 |   4 |
# |         561 |   0 |   2 |
# |         562 |   0 |   2 |
# |         566 |   0 |   4 |
# |         571 |   1 |   3 |
# |         572 |   0 |   4 |
# |         576 |   0 |   4 |
# |         582 |   2 |   2 |
# |         589 |   1 |   3 |
# |         590 |   0 |   4 |
# |         592 |   2 |   2 |
# |         597 |   0 |   4 |
# |         599 |   1 |   3 |
# |         603 |   0 |   4 |
# |         606 |   1 |   3 |
# |         609 |   1 |   1 |
# |         610 |   0 |   4 |
# |         617 |   0 |   4 |
# |         622 |   0 |   4 |
# |         625 |   0 |   4 |
# |         629 |   0 |   4 |
# |         630 |   1 |   1 |
# |         631 |   0 |   4 |
# |         635 |   0 |   4 |
# |         637 |   0 |   4 |
# |         643 |   0 |   4 |
# |         644 |   0 |   4 |
# |         652 |   0 |   4 |
# |         653 |   0 |   4 |
# |         656 |   0 |   2 |
# |         658 |   0 |   4 |
# |         664 |   0 |   4 |
# |         683 |   1 |   3 |
# |         702 |   0 |   4 |
# |         703 |   0 |   4 |
# |         707 |   0 |   4 |
# |         726 |   0 |   4 |
# |         730 |   0 |   4 |
# |         734 |   0 |   4 |
# |         736 |   0 |   4 |
# |         741 |   0 |   4 |
# |         750 |   0 |   2 |
# |         753 |   2 |   2 |
# |         754 |   0 |   2 |
# |         759 |   0 |   2 |
# |         762 |   0 |   2 |
# |         766 |   0 |   4 |
# |         771 |   0 |   4 |
# |         773 |   0 |   2 |
# |         774 |   0 |   2 |
# |         775 |   0 |   2 |
# |         778 |   2 |   0 |
# |         779 |   0 |   2 |
# |         780 |   0 |   2 |
# |         781 |   0 |   2 |
# |         783 |   0 |   2 |
# |         785 |   0 |   4 |
# |         786 |   0 |   2 |
# |         791 |   0 |   4 |
# |         806 |   0 |   4 |
# |         815 |   0 |   4 |
# |         818 |   1 |   3 |
# |         829 |   0 |   4 |
# |         833 |   0 |   4 |
# |         846 |   0 |   4 |
# |         850 |   0 |   4 |
# |         852 |   0 |   4 |
# |         859 |   1 |   3 |
# |         860 |   1 |   3 |
# |         874 |   0 |   4 |
# |         876 |   0 |   4 |
# |         879 |   1 |   3 |
# |         882 |   0 |   4 |
# |         890 |   0 |   4 |
# |         897 |   0 |   4 |
# |         901 |   0 |   4 |
# |         908 |   1 |   3 |
# |         909 |   0 |   2 |
# |         910 |   1 |   3 |
# |         942 |   0 |   4 |
# |         943 |   0 |   2 |
# |         948 |   0 |   4 |
# |         953 |   0 |   2 |
# |         955 |   0 |   4 |
# |         959 |   0 |   4 |
# |         962 |   0 |   4 |
# |         964 |   0 |   4 |
# |         967 |   3 |   1 |
# |         968 |   1 |   1 |
# |         969 |   0 |   4 |
# |         970 |   0 |   2 |
# |         973 |   0 |   4 |
# |         974 |   0 |   2 |
# |         975 |   0 |   2 |
# |         978 |   0 |   4 |
# |         979 |   0 |   4 |
# |         980 |   2 |   0 |
# |         981 |   0 |   4 |
# |         985 |   0 |   2 |
# |         990 |   0 |   2 |
# |         992 |   0 |   4 |
# |         993 |   0 |   4 |
# |         997 |   0 |   4 |
# |        1017 |   0 |   4 |
# |        1018 |   0 |   4 |
# |        1019 |   0 |   4 |
# |        1020 |   0 |   4 |
# |        1022 |   1 |   3 |
# |        1024 |   0 |   2 |
# |        1025 |   0 |   4 |
# |        1026 |   0 |   2 |
# |        1034 |   0 |   2 |
# |        1038 |   1 |   1 |
# |        1043 |   0 |   2 |
# |        1044 |   0 |   4 |
# |        1045 |   0 |   2 |
# |        1047 |   0 |   4 |
# |        1049 |   2 |   0 |
# |        1050 |   1 |   3 |
# |        1052 |   0 |   4 |
# |        1054 |   2 |   2 |
# |        1056 |   0 |   4 |
# |        1058 |   1 |   1 |
# |        1060 |   0 |   2 |
# |        1061 |   1 |   3 |
# |        1063 |   0 |   4 |
# |        1069 |   0 |   2 |
# |        1071 |   0 |   4 |
# |        1072 |   0 |   2 |
# |        1075 |   0 |   4 |
# |        1076 |   0 |   2 |
# |        1078 |   0 |   4 |
# |        1081 |   0 |   4 |
# |        1090 |   0 |   4 |
# |        1094 |   0 |   4 |
# |        1096 |   0 |   2 |
# |        1097 |   0 |   4 |
# |        1099 |   0 |   2 |
# |        1101 |   0 |   2 |
# |        1104 |   0 |   2 |
# |        1106 |   0 |   2 |
# |        1107 |   0 |   2 |
# |        1115 |   0 |   2 |
# |        1116 |   0 |   2 |
# |        1118 |   0 |   4 |
# |        1119 |   0 |   2 |
# |        1121 |   0 |   2 |
# |        1122 |   1 |   3 |
# |        1125 |   0 |   4 |
# |        1129 |   0 |   2 |
# |        1134 |   1 |   3 |
# |        1135 |   0 |   4 |
# |        1136 |   1 |   3 |
# |        1140 |   0 |   2 |
# |        1144 |   0 |   4 |
# |        1153 |   0 |   2 |
# |        1157 |   0 |   4 |
# |        1159 |   0 |   4 |
# |        1163 |   0 |   2 |
# |        1167 |   0 |   4 |
# |        1170 |   0 |   4 |
# |        1171 |   0 |   2 |
# |        1173 |   0 |   4 |
# |        1178 |   0 |   2 |
# |        1179 |   0 |   2 |
# |        1183 |   1 |   3 |
# |        1184 |   0 |   4 |
# |        1187 |   2 |   2 |
# |        1190 |   0 |   4 |
# |        1191 |   0 |   4 |
# |        1194 |   0 |   2 |
# |        1195 |   0 |   4 |
# |        1197 |   2 |   2 |
# |        1201 |   0 |   2 |
# |        1202 |   0 |   2 |
# |        1204 |   0 |   4 |
# |        1213 |   3 |   1 |
# |        1215 |   0 |   4 |
# |        1219 |   0 |   4 |
# |        1222 |   0 |   4 |
# |        1229 |   0 |   4 |
# |        1231 |   0 |   2 |
# |        1233 |   0 |   2 |
# |        1236 |   0 |   2 |
# |        1237 |   0 |   4 |
# |        1244 |   2 |   0 |
# |        1245 |   1 |   3 |
# |        1247 |   0 |   4 |
# |        1252 |   0 |   4 |
# |        1254 |   0 |   4 |
# |        1261 |   0 |   2 |
# |        1263 |   1 |   3 |
# |        1264 |   0 |   2 |
# |        1266 |   0 |   4 |
# |        1267 |   0 |   2 |
# |        1270 |   0 |   4 |
# |        1273 |   0 |   4 |
# |        1281 |   0 |   4 |
# |        1284 |   0 |   2 |
# |        1286 |   0 |   2 |
# |        1294 |   0 |   4 |
# |        1300 |   0 |   2 |
# |        1311 |   2 |   2 |
# |        1312 |   0 |   4 |
# |        1314 |   0 |   4 |
# |        1316 |   0 |   4 |
# |        1323 |   0 |   4 |
# |        1326 |   0 |   4 |
# |        1327 |   0 |   4 |
# |        1330 |   0 |   2 |
# |        1331 |   0 |   4 |
# |        1333 |   0 |   2 |
# |        1335 |   0 |   2 |
# |        1336 |   0 |   2 |
# |        1337 |   0 |   4 |
# |        1338 |   3 |   1 |
# +-------------+-----+-----+
# +-------------+------+------+
# |   job_ad_id |    1 |    2 |
# |-------------+------+------|
# |           1 | 0    | 1    |
# |           2 | 0    | 1    |
# |           3 | 0    | 1    |
# |           4 | 0    | 1    |
# |           6 | 0    | 1    |
# |           8 | 0    | 1    |
# |          11 | 0    | 1    |
# |          12 | 0    | 1    |
# |          13 | 0    | 1    |
# |          14 | 0    | 1    |
# |          20 | 0    | 1    |
# |          21 | 0    | 1    |
# |          23 | 0    | 1    |
# |          25 | 0    | 1    |
# |          31 | 0    | 1    |
# |          32 | 0    | 1    |
# |          33 | 0    | 1    |
# |          36 | 0    | 1    |
# |          38 | 0    | 1    |
# |          39 | 0    | 1    |
# |          40 | 0.5  | 0.5  |
# |          45 | 0    | 1    |
# |          46 | 0    | 1    |
# |          50 | 0    | 1    |
# |          57 | 0    | 1    |
# |          60 | 0    | 1    |
# |          61 | 0    | 1    |
# |          62 | 0    | 1    |
# |          63 | 0    | 1    |
# |          64 | 0    | 1    |
# |          66 | 0    | 1    |
# |          69 | 0    | 1    |
# |          70 | 0    | 1    |
# |          73 | 0    | 1    |
# |          76 | 0    | 1    |
# |          77 | 0    | 1    |
# |          78 | 0    | 1    |
# |          80 | 0    | 1    |
# |          81 | 0    | 1    |
# |          84 | 0    | 1    |
# |          86 | 0    | 1    |
# |          87 | 0.25 | 0.75 |
# |          95 | 0    | 1    |
# |          97 | 0    | 1    |
# |          99 | 0    | 1    |
# |         100 | 0    | 1    |
# |         101 | 0.5  | 0.5  |
# |         103 | 0    | 1    |
# |         104 | 0    | 1    |
# |         105 | 0    | 1    |
# |         107 | 0    | 1    |
# |         110 | 0    | 1    |
# |         111 | 0    | 1    |
# |         114 | 0    | 1    |
# |         116 | 0    | 1    |
# |         117 | 0    | 1    |
# |         122 | 0    | 1    |
# |         124 | 0    | 1    |
# |         125 | 0    | 1    |
# |         126 | 0    | 1    |
# |         127 | 0    | 1    |
# |         129 | 0    | 1    |
# |         130 | 0    | 1    |
# |         131 | 0    | 1    |
# |         133 | 0    | 1    |
# |         134 | 0    | 1    |
# |         135 | 0    | 1    |
# |         137 | 0    | 1    |
# |         143 | 0    | 1    |
# |         145 | 0    | 1    |
# |         146 | 0    | 1    |
# |         148 | 0    | 1    |
# |         153 | 0    | 1    |
# |         155 | 0    | 1    |
# |         158 | 0    | 1    |
# |         161 | 0    | 1    |
# |         162 | 0    | 1    |
# |         163 | 0    | 1    |
# |         164 | 0    | 1    |
# |         168 | 0    | 1    |
# |         169 | 0    | 1    |
# |         170 | 0    | 1    |
# |         173 | 0    | 1    |
# |         174 | 0    | 1    |
# |         177 | 0    | 1    |
# |         178 | 1    | 0    |
# |         179 | 0    | 1    |
# |         182 | 0    | 1    |
# |         185 | 0    | 1    |
# |         186 | 0    | 1    |
# |         187 | 0    | 1    |
# |         188 | 0    | 1    |
# |         189 | 0    | 1    |
# |         190 | 0    | 1    |
# |         191 | 0    | 1    |
# |         193 | 0    | 1    |
# |         196 | 0    | 1    |
# |         201 | 0    | 1    |
# |         203 | 0    | 1    |
# |         206 | 0    | 1    |
# |         207 | 0    | 1    |
# |         210 | 0    | 1    |
# |         218 | 0    | 1    |
# |         220 | 0    | 1    |
# |         224 | 0    | 1    |
# |         225 | 0    | 1    |
# |         226 | 0    | 1    |
# |         227 | 0    | 1    |
# |         228 | 0    | 1    |
# |         229 | 0    | 1    |
# |         234 | 0    | 1    |
# |         237 | 0    | 1    |
# |         240 | 0    | 1    |
# |         244 | 0    | 1    |
# |         245 | 0    | 1    |
# |         246 | 0    | 1    |
# |         254 | 0.25 | 0.75 |
# |         259 | 0    | 1    |
# |         261 | 0    | 1    |
# |         264 | 0    | 1    |
# |         266 | 0    | 1    |
# |         272 | 0    | 1    |
# |         275 | 0    | 1    |
# |         279 | 0    | 1    |
# |         282 | 0    | 1    |
# |         285 | 0    | 1    |
# |         288 | 0.5  | 0.5  |
# |         295 | 0    | 1    |
# |         298 | 0    | 1    |
# |         305 | 0.25 | 0.75 |
# |         319 | 0    | 1    |
# |         320 | 0.25 | 0.75 |
# |         321 | 0    | 1    |
# |         331 | 0    | 1    |
# |         333 | 0.5  | 0.5  |
# |         335 | 0    | 1    |
# |         341 | 0.75 | 0.25 |
# |         345 | 0    | 1    |
# |         346 | 0    | 1    |
# |         348 | 0    | 1    |
# |         353 | 0    | 1    |
# |         354 | 0.75 | 0.25 |
# |         355 | 0    | 1    |
# |         357 | 0.25 | 0.75 |
# |         358 | 0    | 1    |
# |         364 | 0    | 1    |
# |         365 | 0    | 1    |
# |         366 | 0.75 | 0.25 |
# |         369 | 0    | 1    |
# |         370 | 0.25 | 0.75 |
# |         372 | 0    | 1    |
# |         373 | 0    | 1    |
# |         381 | 0.5  | 0.5  |
# |         385 | 0    | 1    |
# |         387 | 0    | 1    |
# |         391 | 0    | 1    |
# |         394 | 0    | 1    |
# |         399 | 0    | 1    |
# |         400 | 0    | 1    |
# |         406 | 0    | 1    |
# |         407 | 0    | 1    |
# |         410 | 0.5  | 0.5  |
# |         414 | 0.5  | 0.5  |
# |         415 | 0    | 1    |
# |         416 | 0    | 1    |
# |         418 | 1    | 0    |
# |         420 | 0    | 1    |
# |         422 | 0    | 1    |
# |         423 | 0    | 1    |
# |         424 | 0    | 1    |
# |         425 | 0    | 1    |
# |         427 | 0    | 1    |
# |         430 | 0    | 1    |
# |         431 | 0    | 1    |
# |         434 | 0    | 1    |
# |         435 | 0    | 1    |
# |         437 | 0    | 1    |
# |         441 | 1    | 0    |
# |         453 | 0    | 1    |
# |         454 | 0    | 1    |
# |         456 | 0    | 1    |
# |         458 | 0.25 | 0.75 |
# |         459 | 0    | 1    |
# |         462 | 0.75 | 0.25 |
# |         464 | 0    | 1    |
# |         465 | 0    | 1    |
# |         469 | 0    | 1    |
# |         470 | 0    | 1    |
# |         471 | 0    | 1    |
# |         473 | 0    | 1    |
# |         475 | 0    | 1    |
# |         481 | 0    | 1    |
# |         482 | 0    | 1    |
# |         485 | 0.25 | 0.75 |
# |         495 | 0.25 | 0.75 |
# |         498 | 0    | 1    |
# |         505 | 0    | 1    |
# |         507 | 0    | 1    |
# |         512 | 0    | 1    |
# |         515 | 0    | 1    |
# |         519 | 0    | 1    |
# |         523 | 0    | 1    |
# |         535 | 0    | 1    |
# |         541 | 0    | 1    |
# |         547 | 0    | 1    |
# |         551 | 0    | 1    |
# |         552 | 0.5  | 0.5  |
# |         555 | 0    | 1    |
# |         558 | 0    | 1    |
# |         561 | 0    | 1    |
# |         562 | 0    | 1    |
# |         566 | 0    | 1    |
# |         571 | 0.25 | 0.75 |
# |         572 | 0    | 1    |
# |         576 | 0    | 1    |
# |         582 | 0.5  | 0.5  |
# |         589 | 0.25 | 0.75 |
# |         590 | 0    | 1    |
# |         592 | 0.5  | 0.5  |
# |         597 | 0    | 1    |
# |         599 | 0.25 | 0.75 |
# |         603 | 0    | 1    |
# |         606 | 0.25 | 0.75 |
# |         609 | 0.5  | 0.5  |
# |         610 | 0    | 1    |
# |         617 | 0    | 1    |
# |         622 | 0    | 1    |
# |         625 | 0    | 1    |
# |         629 | 0    | 1    |
# |         630 | 0.5  | 0.5  |
# |         631 | 0    | 1    |
# |         635 | 0    | 1    |
# |         637 | 0    | 1    |
# |         643 | 0    | 1    |
# |         644 | 0    | 1    |
# |         652 | 0    | 1    |
# |         653 | 0    | 1    |
# |         656 | 0    | 1    |
# |         658 | 0    | 1    |
# |         664 | 0    | 1    |
# |         683 | 0.25 | 0.75 |
# |         702 | 0    | 1    |
# |         703 | 0    | 1    |
# |         707 | 0    | 1    |
# |         726 | 0    | 1    |
# |         730 | 0    | 1    |
# |         734 | 0    | 1    |
# |         736 | 0    | 1    |
# |         741 | 0    | 1    |
# |         750 | 0    | 1    |
# |         753 | 0.5  | 0.5  |
# |         754 | 0    | 1    |
# |         759 | 0    | 1    |
# |         762 | 0    | 1    |
# |         766 | 0    | 1    |
# |         771 | 0    | 1    |
# |         773 | 0    | 1    |
# |         774 | 0    | 1    |
# |         775 | 0    | 1    |
# |         778 | 1    | 0    |
# |         779 | 0    | 1    |
# |         780 | 0    | 1    |
# |         781 | 0    | 1    |
# |         783 | 0    | 1    |
# |         785 | 0    | 1    |
# |         786 | 0    | 1    |
# |         791 | 0    | 1    |
# |         806 | 0    | 1    |
# |         815 | 0    | 1    |
# |         818 | 0.25 | 0.75 |
# |         829 | 0    | 1    |
# |         833 | 0    | 1    |
# |         846 | 0    | 1    |
# |         850 | 0    | 1    |
# |         852 | 0    | 1    |
# |         859 | 0.25 | 0.75 |
# |         860 | 0.25 | 0.75 |
# |         874 | 0    | 1    |
# |         876 | 0    | 1    |
# |         879 | 0.25 | 0.75 |
# |         882 | 0    | 1    |
# |         890 | 0    | 1    |
# |         897 | 0    | 1    |
# |         901 | 0    | 1    |
# |         908 | 0.25 | 0.75 |
# |         909 | 0    | 1    |
# |         910 | 0.25 | 0.75 |
# |         942 | 0    | 1    |
# |         943 | 0    | 1    |
# |         948 | 0    | 1    |
# |         953 | 0    | 1    |
# |         955 | 0    | 1    |
# |         959 | 0    | 1    |
# |         962 | 0    | 1    |
# |         964 | 0    | 1    |
# |         967 | 0.75 | 0.25 |
# |         968 | 0.5  | 0.5  |
# |         969 | 0    | 1    |
# |         970 | 0    | 1    |
# |         973 | 0    | 1    |
# |         974 | 0    | 1    |
# |         975 | 0    | 1    |
# |         978 | 0    | 1    |
# |         979 | 0    | 1    |
# |         980 | 1    | 0    |
# |         981 | 0    | 1    |
# |         985 | 0    | 1    |
# |         990 | 0    | 1    |
# |         992 | 0    | 1    |
# |         993 | 0    | 1    |
# |         997 | 0    | 1    |
# |        1017 | 0    | 1    |
# |        1018 | 0    | 1    |
# |        1019 | 0    | 1    |
# |        1020 | 0    | 1    |
# |        1022 | 0.25 | 0.75 |
# |        1024 | 0    | 1    |
# |        1025 | 0    | 1    |
# |        1026 | 0    | 1    |
# |        1034 | 0    | 1    |
# |        1038 | 0.5  | 0.5  |
# |        1043 | 0    | 1    |
# |        1044 | 0    | 1    |
# |        1045 | 0    | 1    |
# |        1047 | 0    | 1    |
# |        1049 | 1    | 0    |
# |        1050 | 0.25 | 0.75 |
# |        1052 | 0    | 1    |
# |        1054 | 0.5  | 0.5  |
# |        1056 | 0    | 1    |
# |        1058 | 0.5  | 0.5  |
# |        1060 | 0    | 1    |
# |        1061 | 0.25 | 0.75 |
# |        1063 | 0    | 1    |
# |        1069 | 0    | 1    |
# |        1071 | 0    | 1    |
# |        1072 | 0    | 1    |
# |        1075 | 0    | 1    |
# |        1076 | 0    | 1    |
# |        1078 | 0    | 1    |
# |        1081 | 0    | 1    |
# |        1090 | 0    | 1    |
# |        1094 | 0    | 1    |
# |        1096 | 0    | 1    |
# |        1097 | 0    | 1    |
# |        1099 | 0    | 1    |
# |        1101 | 0    | 1    |
# |        1104 | 0    | 1    |
# |        1106 | 0    | 1    |
# |        1107 | 0    | 1    |
# |        1115 | 0    | 1    |
# |        1116 | 0    | 1    |
# |        1118 | 0    | 1    |
# |        1119 | 0    | 1    |
# |        1121 | 0    | 1    |
# |        1122 | 0.25 | 0.75 |
# |        1125 | 0    | 1    |
# |        1129 | 0    | 1    |
# |        1134 | 0.25 | 0.75 |
# |        1135 | 0    | 1    |
# |        1136 | 0.25 | 0.75 |
# |        1140 | 0    | 1    |
# |        1144 | 0    | 1    |
# |        1153 | 0    | 1    |
# |        1157 | 0    | 1    |
# |        1159 | 0    | 1    |
# |        1163 | 0    | 1    |
# |        1167 | 0    | 1    |
# |        1170 | 0    | 1    |
# |        1171 | 0    | 1    |
# |        1173 | 0    | 1    |
# |        1178 | 0    | 1    |
# |        1179 | 0    | 1    |
# |        1183 | 0.25 | 0.75 |
# |        1184 | 0    | 1    |
# |        1187 | 0.5  | 0.5  |
# |        1190 | 0    | 1    |
# |        1191 | 0    | 1    |
# |        1194 | 0    | 1    |
# |        1195 | 0    | 1    |
# |        1197 | 0.5  | 0.5  |
# |        1201 | 0    | 1    |
# |        1202 | 0    | 1    |
# |        1204 | 0    | 1    |
# |        1213 | 0.75 | 0.25 |
# |        1215 | 0    | 1    |
# |        1219 | 0    | 1    |
# |        1222 | 0    | 1    |
# |        1229 | 0    | 1    |
# |        1231 | 0    | 1    |
# |        1233 | 0    | 1    |
# |        1236 | 0    | 1    |
# |        1237 | 0    | 1    |
# |        1244 | 1    | 0    |
# |        1245 | 0.25 | 0.75 |
# |        1247 | 0    | 1    |
# |        1252 | 0    | 1    |
# |        1254 | 0    | 1    |
# |        1261 | 0    | 1    |
# |        1263 | 0.25 | 0.75 |
# |        1264 | 0    | 1    |
# |        1266 | 0    | 1    |
# |        1267 | 0    | 1    |
# |        1270 | 0    | 1    |
# |        1273 | 0    | 1    |
# |        1281 | 0    | 1    |
# |        1284 | 0    | 1    |
# |        1286 | 0    | 1    |
# |        1294 | 0    | 1    |
# |        1300 | 0    | 1    |
# |        1311 | 0.5  | 0.5  |
# |        1312 | 0    | 1    |
# |        1314 | 0    | 1    |
# |        1316 | 0    | 1    |
# |        1323 | 0    | 1    |
# |        1326 | 0    | 1    |
# |        1327 | 0    | 1    |
# |        1330 | 0    | 1    |
# |        1331 | 0    | 1    |
# |        1333 | 0    | 1    |
# |        1335 | 0    | 1    |
# |        1336 | 0    | 1    |
# |        1337 | 0    | 1    |
# |        1338 | 0.75 | 0.25 |
# +-------------+------+------+
# The p-value (Chi-square test of independenc: job_ad_id and received_callback ):
# 4.1641159313674235e-25
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# received_callback
# +------------+-----+-----+
# | job_city   |   1 |   2 |
# |------------+-----+-----|
# | Boston     |  34 | 656 |
# | Chicago    |  65 | 747 |
# +------------+-----+-----+
# +------------+-----------+----------+
# | job_city   |         1 |        2 |
# |------------+-----------+----------|
# | Boston     | 0.0492754 | 0.950725 |
# | Chicago    | 0.0800493 | 0.919951 |
# +------------+-----------+----------+
# The p-value (Chi-square test of independenc: job_city and received_callback ):
# 0.02196101076667979
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# received_callback
# +-------------------------------+-----+-----+
# | job_industry                  |   1 |   2 |
# |-------------------------------+-----+-----|
# | business_and_personal_service |  29 | 393 |
# | finance_insurance_real_estate |   8 | 112 |
# | manufacturing                 |   9 | 165 |
# | other_service                 |  16 | 260 |
# | transportation_communication  |   2 |  34 |
# | wholesale_and_retail_trade    |  35 | 439 |
# +-------------------------------+-----+-----+
# +-------------------------------+-----------+----------+
# | job_industry                  |         1 |        2 |
# |-------------------------------+-----------+----------|
# | business_and_personal_service | 0.0687204 | 0.93128  |
# | finance_insurance_real_estate | 0.0666667 | 0.933333 |
# | manufacturing                 | 0.0517241 | 0.948276 |
# | other_service                 | 0.057971  | 0.942029 |
# | transportation_communication  | 0.0555556 | 0.944444 |
# | wholesale_and_retail_trade    | 0.0738397 | 0.92616  |
# +-------------------------------+-----------+----------+
# The p-value (Chi-square test of independenc: job_industry and received_callback ):
# 0.9183931521757931
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# received_callback
# +--------------+-----+-----+
# | job_type     |   1 |   2 |
# |--------------+-----+-----|
# | clerical     |   2 |  90 |
# | manager      |  34 | 316 |
# | retail_sales |  15 | 245 |
# | sales_rep    |  14 | 248 |
# | secretary    |  24 | 378 |
# | supervisor   |  10 | 126 |
# +--------------+-----+-----+
# +--------------+-----------+----------+
# | job_type     |         1 |        2 |
# |--------------+-----------+----------|
# | clerical     | 0.0217391 | 0.978261 |
# | manager      | 0.0971429 | 0.902857 |
# | retail_sales | 0.0576923 | 0.942308 |
# | sales_rep    | 0.0534351 | 0.946565 |
# | secretary    | 0.0597015 | 0.940299 |
# | supervisor   | 0.0735294 | 0.926471 |
# +--------------+-----------+----------+
# The p-value (Chi-square test of independenc: job_type and received_callback ):
# 0.08146139389616085
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# received_callback
# +----------------------+-----+------+
# |   job_fed_contractor |   1 |    2 |
# |----------------------+-----+------|
# |                    0 |  86 | 1240 |
# |                    1 |  13 |  163 |
# +----------------------+-----+------+
# +----------------------+-----------+----------+
# |   job_fed_contractor |         1 |        2 |
# |----------------------+-----------+----------|
# |                    0 | 0.0648567 | 0.935143 |
# |                    1 | 0.0738636 | 0.926136 |
# +----------------------+-----------+----------+
# The p-value (Chi-square test of independenc: job_fed_contractor and received_callback ):
# 0.7711933333211018
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# received_callback
# +--------------------------+-----+-----+
# |   job_equal_opp_employer |   1 |   2 |
# |--------------------------+-----+-----|
# |                        0 |  53 | 771 |
# |                        1 |  46 | 632 |
# +--------------------------+-----+-----+
# +--------------------------+-----------+----------+
# |   job_equal_opp_employer |         1 |        2 |
# |--------------------------+-----------+----------|
# |                        0 | 0.0643204 | 0.93568  |
# |                        1 | 0.0678466 | 0.932153 |
# +--------------------------+-----------+----------+
# The p-value (Chi-square test of independenc: job_equal_opp_employer and received_callback ):
# 0.865328427080458
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# received_callback
# +-----------------+-----+-----+
# | job_ownership   |   1 |   2 |
# |-----------------+-----+-----|
# | nonprofit       |   8 | 150 |
# | private         |  67 | 959 |
# | public          |  14 | 204 |
# | unknown         |  10 |  90 |
# +-----------------+-----+-----+
# +-----------------+-----------+----------+
# | job_ownership   |         1 |        2 |
# |-----------------+-----------+----------|
# | nonprofit       | 0.0506329 | 0.949367 |
# | private         | 0.0653021 | 0.934698 |
# | public          | 0.0642202 | 0.93578  |
# | unknown         | 0.1       | 0.9      |
# +-----------------+-----------+----------+
# The p-value (Chi-square test of independenc: job_ownership and received_callback ):
# 0.47479037763519305
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# received_callback
# +---------------+-----+------+
# |   job_req_any |   1 |    2 |
# |---------------+-----+------|
# |             1 |  99 | 1403 |
# +---------------+-----+------+
# +---------------+-----------+----------+
# |   job_req_any |         1 |        2 |
# |---------------+-----------+----------|
# |             1 | 0.0659121 | 0.934088 |
# +---------------+-----------+----------+
# The p-value (Chi-square test of independenc: job_req_any and received_callback ):
# 1.0
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# received_callback
# +-------------------------+-----+------+
# |   job_req_communication |   1 |    2 |
# |-------------------------+-----+------|
# |                       0 |  88 | 1266 |
# |                       1 |  11 |  137 |
# +-------------------------+-----+------+
# +-------------------------+-----------+----------+
# |   job_req_communication |         1 |        2 |
# |-------------------------+-----------+----------|
# |                       0 | 0.0649926 | 0.935007 |
# |                       1 | 0.0743243 | 0.925676 |
# +-------------------------+-----------+----------+
# The p-value (Chi-square test of independenc: job_req_communication and received_callback ):
# 0.7949076017654819
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# received_callback
# +---------------------+-----+------+
# |   job_req_education |   1 |    2 |
# |---------------------+-----+------|
# |                   0 |  88 | 1116 |
# |                   1 |  11 |  287 |
# +---------------------+-----+------+
# +---------------------+-----------+----------+
# |   job_req_education |         1 |        2 |
# |---------------------+-----------+----------|
# |                   0 | 0.0730897 | 0.92691  |
# |                   1 | 0.0369128 | 0.963087 |
# +---------------------+-----------+----------+
# The p-value (Chi-square test of independenc: job_req_education and received_callback ):
# 0.03375053031108439
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# received_callback
# +--------------------------+-----+-----+
# | job_req_min_experience   |   1 |   2 |
# |--------------------------+-----+-----|
# | 0                        |   0 |   4 |
# | 0.5                      |   1 |   7 |
# | 1                        |   8 | 104 |
# | 10                       |   1 |  13 |
# | 2                        |  22 | 222 |
# | 3                        |  11 | 232 |
# | 4                        |   1 |   7 |
# | 5                        |   6 | 115 |
# | 6                        |   0 |   4 |
# | 7                        |   0 |  12 |
# | 8                        |   0 |   8 |
# | some                     |  49 | 675 |
# +--------------------------+-----+-----+
# +--------------------------+-----------+----------+
# | job_req_min_experience   |         1 |        2 |
# |--------------------------+-----------+----------|
# | 0                        | 0         | 1        |
# | 0.5                      | 0.125     | 0.875    |
# | 1                        | 0.0714286 | 0.928571 |
# | 10                       | 0.0714286 | 0.928571 |
# | 2                        | 0.0901639 | 0.909836 |
# | 3                        | 0.0452675 | 0.954733 |
# | 4                        | 0.125     | 0.875    |
# | 5                        | 0.0495868 | 0.950413 |
# | 6                        | 0         | 1        |
# | 7                        | 0         | 1        |
# | 8                        | 0         | 1        |
# | some                     | 0.0676796 | 0.93232  |
# +--------------------------+-----------+----------+
# The p-value (Chi-square test of independenc: job_req_min_experience and received_callback ):
# 0.7556355101486558
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# received_callback
# +--------------------+-----+-----+
# |   job_req_computer |   1 |   2 |
# |--------------------+-----+-----|
# |                  0 |  58 | 863 |
# |                  1 |  41 | 540 |
# +--------------------+-----+-----+
# +--------------------+----------+----------+
# |   job_req_computer |        1 |        2 |
# |--------------------+----------+----------|
# |                  0 | 0.062975 | 0.937025 |
# |                  1 | 0.070568 | 0.929432 |
# +--------------------+----------+----------+
# The p-value (Chi-square test of independenc: job_req_computer and received_callback ):
# 0.6377645756281797
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# received_callback
# +------------------------+-----+------+
# |   job_req_organization |   1 |    2 |
# |------------------------+-----+------|
# |                      0 |  98 | 1330 |
# |                      1 |   1 |   73 |
# +------------------------+-----+------+
# +------------------------+-----------+----------+
# |   job_req_organization |         1 |        2 |
# |------------------------+-----------+----------|
# |                      0 | 0.0686275 | 0.931373 |
# |                      1 | 0.0135135 | 0.986486 |
# +------------------------+-----------+----------+
# The p-value (Chi-square test of independenc: job_req_organization and received_callback ):
# 0.10462542739031237
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# received_callback
# +------------------+-----+------+
# | job_req_school   |   1 |    2 |
# |------------------+-----+------|
# | college          |   6 |  112 |
# | high_school_grad |   0 |   28 |
# | none_listed      |  88 | 1116 |
# | some_college     |   5 |  147 |
# +------------------+-----+------+
# +------------------+-----------+----------+
# | job_req_school   |         1 |        2 |
# |------------------+-----------+----------|
# | college          | 0.0508475 | 0.949153 |
# | high_school_grad | 0         | 1        |
# | none_listed      | 0.0730897 | 0.92691  |
# | some_college     | 0.0328947 | 0.967105 |
# +------------------+-----------+----------+
# The p-value (Chi-square test of independenc: job_req_school and received_callback ):
# 0.10639919065951538
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# received_callback
# +-------------+-----+-----+
# |   firstname |   1 |   2 |
# |-------------+-----+-----|
# |           1 |  61 | 708 |
# |           2 |  38 | 695 |
# +-------------+-----+-----+
# +-------------+-----------+----------+
# |   firstname |         1 |        2 |
# |-------------+-----------+----------|
# |           1 | 0.0793238 | 0.920676 |
# |           2 | 0.0518417 | 0.948158 |
# +-------------+-----------+----------+
# The p-value (Chi-square test of independenc: firstname and received_callback ):
# 0.04119113067632141
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# received_callback
# +--------+-----+-----+
# | race   |   1 |   2 |
# |--------+-----+-----|
# | black  |  39 | 712 |
# | white  |  60 | 691 |
# +--------+-----+-----+
# +--------+-----------+----------+
# | race   |         1 |        2 |
# |--------+-----------+----------|
# | black  | 0.0519308 | 0.948069 |
# | white  | 0.0798935 | 0.920107 |
# +--------+-----------+----------+
# The p-value (Chi-square test of independenc: race and received_callback ):
# 0.03754521906556084
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# received_callback
# +----------+-----+-----+
# | gender   |   1 |   2 |
# |----------+-----+-----|
# | f        |  71 | 994 |
# | m        |  28 | 409 |
# +----------+-----+-----+
# +----------+-----------+----------+
# | gender   |         1 |        2 |
# |----------+-----------+----------|
# | f        | 0.0666667 | 0.933333 |
# | m        | 0.0640732 | 0.935927 |
# +----------+-----------+----------+
# The p-value (Chi-square test of independenc: gender and received_callback ):
# 0.9445848749831235
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# received_callback
# +-----------------+-----+------+
# |   years_college |   1 |    2 |
# |-----------------+-----+------|
# |               0 |   1 |   22 |
# |               1 |   1 |    8 |
# |               2 |   7 |   61 |
# |               3 |  10 |  202 |
# |               4 |  80 | 1110 |
# +-----------------+-----+------+
# +-----------------+-----------+----------+
# |   years_college |         1 |        2 |
# |-----------------+-----------+----------|
# |               0 | 0.0434783 | 0.956522 |
# |               1 | 0.111111  | 0.888889 |
# |               2 | 0.102941  | 0.897059 |
# |               3 | 0.0471698 | 0.95283  |
# |               4 | 0.0672269 | 0.932773 |
# +-----------------+-----------+----------+
# The p-value (Chi-square test of independenc: years_college and received_callback ):
# 0.5178491464649163
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# received_callback
# +------------------+-----+------+
# |   college_degree |   1 |    2 |
# |------------------+-----+------|
# |                0 |  19 |  293 |
# |                1 |  80 | 1110 |
# +------------------+-----+------+
# +------------------+-----------+----------+
# |   college_degree |         1 |        2 |
# |------------------+-----------+----------|
# |                0 | 0.0608974 | 0.939103 |
# |                1 | 0.0672269 | 0.932773 |
# +------------------+-----------+----------+
# The p-value (Chi-square test of independenc: college_degree and received_callback ):
# 0.7849384508201792
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# received_callback
# +----------+-----+------+
# |   honors |   1 |    2 |
# |----------+-----+------|
# |        0 |  91 | 1337 |
# |        1 |   8 |   66 |
# +----------+-----+------+
# +----------+-----------+----------+
# |   honors |         1 |        2 |
# |----------+-----------+----------|
# |        0 | 0.0637255 | 0.936275 |
# |        1 | 0.108108  | 0.891892 |
# +----------+-----------+----------+
# The p-value (Chi-square test of independenc: honors and received_callback ):
# 0.20764423821058073
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# received_callback
# +------------------------+-----+-----+
# |   worked_during_school |   1 |   2 |
# |------------------------+-----+-----|
# |                      0 |  51 | 625 |
# |                      1 |  48 | 778 |
# +------------------------+-----+-----+
# +------------------------+-----------+----------+
# |   worked_during_school |         1 |        2 |
# |------------------------+-----------+----------|
# |                      0 | 0.0754438 | 0.924556 |
# |                      1 | 0.0581114 | 0.941889 |
# +------------------------+-----------+----------+
# The p-value (Chi-square test of independenc: worked_during_school and received_callback ):
# 0.21412145226255427
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# received_callback
# +--------------------+-----+-----+
# |   years_experience |   1 |   2 |
# |--------------------+-----+-----|
# |                  1 |   1 |   5 |
# |                  2 |   5 | 104 |
# |                  3 |   2 |  60 |
# |                  4 |  14 | 134 |
# |                  5 |  10 | 145 |
# |                  6 |  17 | 219 |
# |                  7 |  10 | 154 |
# |                  8 |  13 | 211 |
# |                  9 |   0 |  36 |
# |                 10 |   4 |  39 |
# |                 11 |   2 |  39 |
# |                 12 |   3 |  25 |
# |                 13 |   7 |  41 |
# |                 14 |   1 |  49 |
# |                 15 |   0 |   7 |
# |                 16 |   0 |  12 |
# |                 17 |   0 |   2 |
# |                 18 |   3 |  35 |
# |                 19 |   0 |   8 |
# |                 20 |   0 |  12 |
# |                 21 |   3 |  16 |
# |                 22 |   0 |   3 |
# |                 23 |   0 |   5 |
# |                 25 |   0 |   3 |
# |                 26 |   4 |  38 |
# |                 44 |   0 |   1 |
# +--------------------+-----+-----+
# +--------------------+-----------+----------+
# |   years_experience |         1 |        2 |
# |--------------------+-----------+----------|
# |                  1 | 0.166667  | 0.833333 |
# |                  2 | 0.0458716 | 0.954128 |
# |                  3 | 0.0322581 | 0.967742 |
# |                  4 | 0.0945946 | 0.905405 |
# |                  5 | 0.0645161 | 0.935484 |
# |                  6 | 0.0720339 | 0.927966 |
# |                  7 | 0.0609756 | 0.939024 |
# |                  8 | 0.0580357 | 0.941964 |
# |                  9 | 0         | 1        |
# |                 10 | 0.0930233 | 0.906977 |
# |                 11 | 0.0487805 | 0.95122  |
# |                 12 | 0.107143  | 0.892857 |
# |                 13 | 0.145833  | 0.854167 |
# |                 14 | 0.02      | 0.98     |
# |                 15 | 0         | 1        |
# |                 16 | 0         | 1        |
# |                 17 | 0         | 1        |
# |                 18 | 0.0789474 | 0.921053 |
# |                 19 | 0         | 1        |
# |                 20 | 0         | 1        |
# |                 21 | 0.157895  | 0.842105 |
# |                 22 | 0         | 1        |
# |                 23 | 0         | 1        |
# |                 25 | 0         | 1        |
# |                 26 | 0.0952381 | 0.904762 |
# |                 44 | 0         | 1        |
# +--------------------+-----------+----------+
# The p-value (Chi-square test of independenc: years_experience and received_callback ):
# 0.5767471644339353
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# received_callback
# +-------------------+-----+------+
# |   computer_skills |   1 |    2 |
# |-------------------+-----+------|
# |                 0 |  26 |  272 |
# |                 1 |  73 | 1131 |
# +-------------------+-----+------+
# +-------------------+-----------+----------+
# |   computer_skills |         1 |        2 |
# |-------------------+-----------+----------|
# |                 0 | 0.0872483 | 0.912752 |
# |                 1 | 0.0606312 | 0.939369 |
# +-------------------+-----------+----------+
# The p-value (Chi-square test of independenc: computer_skills and received_callback ):
# 0.12661989861031298
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# received_callback
# +------------------+-----+------+
# |   special_skills |   1 |    2 |
# |------------------+-----+------|
# |                0 |  58 | 1011 |
# |                1 |  41 |  392 |
# +------------------+-----+------+
# +------------------+-----------+----------+
# |   special_skills |         1 |        2 |
# |------------------+-----------+----------|
# |                0 | 0.0542563 | 0.945744 |
# |                1 | 0.0946882 | 0.905312 |
# +------------------+-----------+----------+
# The p-value (Chi-square test of independenc: special_skills and received_callback ):
# 0.006037532447359481
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# received_callback
# +-------------+-----+-----+
# |   volunteer |   1 |   2 |
# |-------------+-----+-----|
# |           0 |  65 | 802 |
# |           1 |  34 | 601 |
# +-------------+-----+-----+
# +-------------+-----------+----------+
# |   volunteer |         1 |        2 |
# |-------------+-----------+----------|
# |           0 | 0.0749712 | 0.925029 |
# |           1 | 0.0535433 | 0.946457 |
# +-------------+-----------+----------+
# The p-value (Chi-square test of independenc: volunteer and received_callback ):
# 0.12159980925700997
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# received_callback
# +------------+-----+------+
# |   military |   1 |    2 |
# |------------+-----+------|
# |          0 |  91 | 1269 |
# |          1 |   8 |  134 |
# +------------+-----+------+
# +------------+-----------+----------+
# |   military |         1 |        2 |
# |------------+-----------+----------|
# |          0 | 0.0669118 | 0.933088 |
# |          1 | 0.056338  | 0.943662 |
# +------------+-----------+----------+
# The p-value (Chi-square test of independenc: military and received_callback ):
# 0.7599907615603839
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# received_callback
# +--------------------+-----+-----+
# |   employment_holes |   1 |   2 |
# |--------------------+-----+-----|
# |                  0 |  53 | 873 |
# |                  1 |  46 | 530 |
# +--------------------+-----+-----+
# +--------------------+-----------+----------+
# |   employment_holes |         1 |        2 |
# |--------------------+-----------+----------|
# |                  0 | 0.0572354 | 0.942765 |
# |                  1 | 0.0798611 | 0.920139 |
# +--------------------+-----------+----------+
# The p-value (Chi-square test of independenc: employment_holes and received_callback ):
# 0.10709276520879606
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# received_callback
# +---------------------+-----+-----+
# |   has_email_address |   1 |   2 |
# |---------------------+-----+-----|
# |                   0 |  54 | 765 |
# |                   1 |  45 | 638 |
# +---------------------+-----+-----+
# +---------------------+-----------+----------+
# |   has_email_address |         1 |        2 |
# |---------------------+-----------+----------|
# |                   0 | 0.0659341 | 0.934066 |
# |                   1 | 0.0658858 | 0.934114 |
# +---------------------+-----------+----------+
# The p-value (Chi-square test of independenc: has_email_address and received_callback ):
# 1.0
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# received_callback
# +------------------+-----+-----+
# | resume_quality   |   1 |   2 |
# |------------------+-----+-----|
# | high             |  49 | 711 |
# | low              |  50 | 692 |
# +------------------+-----+-----+
# +------------------+-----------+----------+
# | resume_quality   |         1 |        2 |
# |------------------+-----------+----------|
# | high             | 0.0644737 | 0.935526 |
# | low              | 0.0673854 | 0.932615 |
# +------------------+-----------+----------+
# The p-value (Chi-square test of independenc: resume_quality and received_callback ):
# 0.901803331637719
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# Dictionary to store p-values
p_values = {}

# Loop through each independent variable
for i in Indep_variables:
    p_values[i] = []  # Initialize an empty list for storing p-values

    for j in Dep_variables:
        # Create contingency table
        contingency = pd.crosstab(df[i], df[j])
        
        # Perform Chi-square test
        _, p, _, _ = chi2_contingency(contingency)
        
        # Store p-value
        p_values[i].append(p)

# Convert dictionary to DataFrame
p_values_df = pd.DataFrame.from_dict(p_values, orient='index', columns=Dep_variables)

# Display the resulting DataFrame
print(p_values_df)
# Out:
#                         received_callback
# job_ad_id                    4.164116e-25
# job_city                     2.196101e-02
# job_industry                 9.183932e-01
# job_type                     8.146139e-02
# job_fed_contractor           7.711933e-01
# job_equal_opp_employer       8.653284e-01
# job_ownership                4.747904e-01
# job_req_any                  1.000000e+00
# job_req_communication        7.949076e-01
# job_req_education            3.375053e-02
# job_req_min_experience       7.556355e-01
# job_req_computer             6.377646e-01
# job_req_organization         1.046254e-01
# job_req_school               1.063992e-01
# firstname                    4.119113e-02
# race                         3.754522e-02
# gender                       9.445849e-01
# years_college                5.178491e-01
# college_degree               7.849385e-01
# honors                       2.076442e-01
# worked_during_school         2.141215e-01
# years_experience             5.767472e-01
# computer_skills              1.266199e-01
# special_skills               6.037532e-03
# volunteer                    1.215998e-01
# military                     7.599908e-01
# employment_holes             1.070928e-01
# has_email_address            1.000000e+00
# resume_quality               9.018033e-01

# %% [markdown]
# Choose 10 variables to use for analysis
#
#
# FEATURES:
#
# resume_quality
# employment_holes
# years_experience
# worked_during_school
# college_degree
# years_college
# firstname
# computer_skills
# special_skills
#
#
#
# LABELS:
#
# received_callback

# %%
df.columns
# Out:
# Index(['job_ad_id', 'job_city', 'job_industry', 'job_type',
#        'job_fed_contractor', 'job_equal_opp_employer', 'job_ownership',
#        'job_req_any', 'job_req_communication', 'job_req_education',
#        'job_req_min_experience', 'job_req_computer', 'job_req_organization',
#        'job_req_school', 'received_callback', 'firstname', 'race', 'gender',
#        'years_college', 'college_degree', 'honors', 'worked_during_school',
#        'years_experience', 'computer_skills', 'special_skills', 'volunteer',
#        'military', 'employment_holes', 'has_email_address', 'resume_quality'],
#       dtype='object')

# %%
df = df.drop(labels=['job_ad_id', 'job_city', 'job_industry', 'job_type',
       'job_fed_contractor', 'job_equal_opp_employer', 'job_ownership',
       'job_req_any', 'job_req_communication', 'job_req_education',
       'job_req_min_experience', 'job_req_computer', 'job_req_organization',
       'job_req_school', 'race', 'gender','volunteer',
       'military','honors','has_email_address'], axis = 1)

# %%
df
# Out:
#       received_callback  firstname  years_college  college_degree  \
# 4                     2          1              3               0
# 7                     2          2              3               0
# 10                    2          2              4               1
# 11                    2          1              4               1
# 23                    2          1              4               1
# ...                 ...        ...            ...             ...
# 4821                  2          2              4               1
# 4858                  2          2              4               1
# 4859                  1          2              4               1
# 4860                  2          1              4               1
# 4861                  1          1              4               1
#
#       worked_during_school  years_experience  computer_skills  special_skills  \
# 4                        1                22                1               0
# 7                        0                21                1               1
# 10                       0                 8                1               1
# 11                       1                 8                1               0
# 23                       0                 7                1               0
# ...                    ...               ...              ...             ...
# 4821                     1                 6                1               0
# 4858                     1                 2                1               0
# 4859                     1                 6                1               0
# 4860                     1                 8                1               0
# 4861                     0                 7                0               0
#
#       employment_holes resume_quality
# 4                    0           high
# 7                    1           high
# 10                   1           high
# 11                   0           high
# 23                   1            low
# ...                ...            ...
# 4821                 0            low
# 4858                 0           high
# 4859                 0            low
# 4860                 0           high
# 4861                 1            low
#
# [1502 rows x 10 columns]

# %%
df.columns.values
# Out:
# array(['received_callback', 'firstname', 'years_college',
#        'college_degree', 'worked_during_school', 'years_experience',
#        'computer_skills', 'special_skills', 'employment_holes',
#        'resume_quality'], dtype=object)

# %% [markdown]
# # Logistic Reg

# %%
# Define model formula :https://www.statsmodels.org/dev/examples/notebooks/generated/glm_weights.html
formula = 'C(received_callback) ~ C(firstname)+ C(college_degree)+ C(worked_during_school) + C(computer_skills) + C(special_skills) + C(employment_holes) + C(resume_quality)+years_college + years_experience'
family_GLM = sm.families.Binomial()

model_GLM = glm(formula = formula, data = df, family = family_GLM ).fit()
print(model_GLM.summary())
# Out:
#                                    Generalized Linear Model Regression Results
# ==================================================================================================================
# Dep. Variable:     ['C(received_callback)[1]', 'C(received_callback)[2]']   No. Observations:                 1502
# Model:                                                                GLM   Df Residuals:                     1492
# Model Family:                                                    Binomial   Df Model:                            9
# Link Function:                                                      Logit   Scale:                          1.0000
# Method:                                                              IRLS   Log-Likelihood:                -356.54
# Date:                                                    Wed, 07 May 2025   Deviance:                       713.07
# Time:                                                            12:54:53   Pearson chi2:                 1.51e+03
# No. Iterations:                                                         6   Pseudo R-squ. (CS):            0.01106
# Covariance Type:                                                nonrobust
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                       -2.5523      0.751     -3.398      0.001      -4.025      -1.080
# C(firstname)[T.2]               -0.4302      0.215     -2.002      0.045      -0.851      -0.009
# C(college_degree)[T.1]           0.3400      0.488      0.697      0.486      -0.616       1.296
# C(worked_during_school)[T.1]     0.0479      0.272      0.176      0.860      -0.485       0.581
# C(computer_skills)[T.1]         -0.3417      0.261     -1.308      0.191      -0.854       0.170
# C(special_skills)[T.1]           0.5926      0.227      2.610      0.009       0.148       1.038
# C(employment_holes)[T.1]         0.2854      0.244      1.168      0.243      -0.193       0.764
# C(resume_quality)[T.low]         0.0103      0.240      0.043      0.966      -0.460       0.480
# years_college                   -0.0941      0.253     -0.372      0.710      -0.590       0.402
# years_experience                 0.0090      0.020      0.446      0.656      -0.030       0.048
# ================================================================================================

# %%
params = model_GLM.params
conf = model_GLM.conf_int()
conf['Odds Ratio'] = params
conf.columns = ['2.5%', '97.2%', 'Odds Ratio']
print(np.exp(conf))
# Out:
#                                   2.5%     97.2%  Odds Ratio
# Intercept                     0.017872  0.339573    0.077904
# C(firstname)[T.2]             0.426855  0.991049    0.650411
# C(college_degree)[T.1]        0.540042  3.655079    1.404954
# C(worked_during_school)[T.1]  0.615876  1.787107    1.049112
# C(computer_skills)[T.1]       0.425807  1.185747    0.710563
# C(special_skills)[T.1]        1.159061  2.822320    1.808657
# C(employment_holes)[T.1]      0.824146  2.147438    1.330339
# C(resume_quality)[T.low]      0.631400  1.616807    1.010372
# years_college                 0.554240  1.494676    0.910170
# years_experience              0.969985  1.049621    1.009018

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
X= df[['firstname', 'years_college',
       'college_degree', 'worked_during_school', 'years_experience',
       'computer_skills', 'special_skills', 'employment_holes','resume_quality']]

y = df[["received_callback"]]-1

# %%
X_encoded = X.drop(columns=["years_college","years_experience"])
X_encoded = pd.get_dummies(X_encoded)
X_encoded[["years_college","years_experience"]] = X[["years_college","years_experience"]]
X_encoded
# Out:
#       firstname  college_degree  worked_during_school  computer_skills  \
# 4             1               0                     1                1
# 7             2               0                     0                1
# 10            2               1                     0                1
# 11            1               1                     1                1
# 23            1               1                     0                1
# ...         ...             ...                   ...              ...
# 4821          2               1                     1                1
# 4858          2               1                     1                1
# 4859          2               1                     1                1
# 4860          1               1                     1                1
# 4861          1               1                     0                0
#
#       special_skills  employment_holes  resume_quality_high  \
# 4                  0                 0                    1
# 7                  1                 1                    1
# 10                 1                 1                    1
# 11                 0                 0                    1
# 23                 0                 1                    0
# ...              ...               ...                  ...
# 4821               0                 0                    0
# 4858               0                 0                    1
# 4859               0                 0                    0
# 4860               0                 0                    1
# 4861               0                 1                    0
#
#       resume_quality_low  years_college  years_experience
# 4                      0              3                22
# 7                      0              3                21
# 10                     0              4                 8
# 11                     0              4                 8
# 23                     1              4                 7
# ...                  ...            ...               ...
# 4821                   1              4                 6
# 4858                   0              4                 2
# 4859                   1              4                 6
# 4860                   0              4                 8
# 4861                   1              4                 7
#
# [1502 rows x 10 columns]

# %%
tree  = DecisionTreeClassifier(random_state=42)
tree.fit(X_encoded, y)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# Visualize the decision tree
plt.figure(figsize=(24, 12))
plot_tree(tree, 
          feature_names=X_encoded.columns.values, 
          class_names=y.columns.values[0],
          filled=True, 
          rounded=True)
plt.title("Decision Tree")
plt.show()

# %%
# Create a DataFrame of feature importances
importance_df = pd.DataFrame({
    "Feature": X_encoded.columns,
    "Importance": tree.feature_importances_
}).sort_values(by="Importance", ascending=False)

print(importance_df)
# Out:
#                 Feature  Importance
# 9      years_experience    0.381818
# 0             firstname    0.170323
# 5      employment_holes    0.108358
# 2  worked_during_school    0.094986
# 7    resume_quality_low    0.086782
# 3       computer_skills    0.059767
# 8         years_college    0.035304
# 6   resume_quality_high    0.025621
# 1        college_degree    0.019880
# 4        special_skills    0.017162

# %%
# Plot top 15 features
plt.figure(figsize=(10, 6))
plt.barh(importance_df["Feature"][:15][::-1], importance_df["Importance"][:15][::-1])
plt.xlabel("Importance")
plt.title("Top 15 Feature Importances")
plt.tight_layout()
plt.show()

# %% [markdown]
# --------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------

# %%
df['resume_quality']=df['resume_quality'].replace('high',3)
df['resume_quality']=df['resume_quality'].replace('low',2)

# %%
from sklearn.tree import DecisionTreeClassifier
import numpy as np

X = df[['received_callback', 'firstname', 'years_college',
       'college_degree', 'worked_during_school', 'years_experience',
       'computer_skills', 'special_skills', 'employment_holes','resume_quality']]

y = df[["received_callback"]]

tree = DecisionTreeClassifier(random_state=0)
tree.fit(X, y)
tree.predict(X)

# %%
from sklearn.tree import export_graphviz
graph_tree=export_graphviz(
    tree,
    out_file=("resume_tree.dot"),
    #feature_names=np.array(['received_callback', 'firstname', 'years_college',
       #'college_degree', 'worked_during_school', 'years_experience',
       #'computer_skills', 'special_skills', 'employment_holes','resume_quality']),
    #class_names=np.array(df.columns[0]),
    rounded=True,
    filled=True
)

# %%
! dot -Tpng  resume_tree.dot -o resume_tree.png

# %% [markdown]
# # Graph Distributions

# %%
#Reread in data because we are using variables that have been dropped
df2=pd.read_csv('resume.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data = df2

sns.countplot(data, x="job_type",color="lightblue",order=["secretary","retail_sales","manager","sales_rep","clerical","supervisor"])
plt.title("Job Type Distribution", fontsize=16)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data = df2



sns.countplot(data, x="job_industry",hue="job_industry",order=["other_service","business_and_personal_service","wholesale_and_retail_trade","finance_insurance_real_estate","manufacturing","transportation_communication"],legend=True).set(xticklabels=[])
plt.title("Job Industry Distribution", fontsize=16)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data = df2



sns.countplot(data, x="job_req_education",hue="job_req_education",legend=True).set(xticklabels=[])
plt.title("Education Required", fontsize=16)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data = df2



sns.countplot(data, x="job_req_min_experience",hue="job_req_min_experience",legend=True, order=['some',0.5,1,2,3,4,5,6,7,8,10]).set(xticklabels=[])
plt.title("Experience Required", fontsize=16)
plt.show()
